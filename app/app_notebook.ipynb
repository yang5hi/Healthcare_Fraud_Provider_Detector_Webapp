# %%
import pandas as pd
X_train=pd.read_csv('data/merged_num_cat_2.csv')
df_num_cat
# Out:
#       Provider  PotentialFraud  DeductibleAmtPaid_mean  DeductibleAmtPaid_max  \
# 0     PRV51001               0              213.600000                 1068.0
# 1     PRV51003               1              502.166667                 1068.0
# 2     PRV51004               0                2.080537                  100.0
# 3     PRV51005               1                3.175966                  200.0
# 4     PRV51007               0               45.333333                 1068.0
# ...        ...             ...                     ...                    ...
# 5405  PRV57759               0                4.642857                   90.0
# 5406  PRV57760               0                0.000000                    0.0
# 5407  PRV57761               0                4.512195                   90.0
# 5408  PRV57762               0                0.000000                    0.0
# 5409  PRV57763               0                3.305085                  100.0
#
# ...

# %%
df_num_cat.iloc[:,:50].describe().T
# Out:
#                                 count           mean           std   min  \
# PotentialFraud                 5410.0       0.093530  2.912013e-01   0.0
# DeductibleAmtPaid_mean         5409.0     155.643175  3.064895e+02   0.0
# DeductibleAmtPaid_max          5409.0     446.900351  4.938822e+02   0.0
# NoOfMonths_PartACov_mean       5410.0      11.919716  3.956823e-01   0.0
# NoOfMonths_PartBCov_mean       5410.0      11.930647  3.106120e-01   0.0
# OPAnnualReimbursementAmt_mean  5410.0    2199.335651  1.301129e+03   0.0
# OPAnnualReimbursementAmt_max   5410.0   14616.208872  1.265322e+04   0.0
# OPAnnualReimbursementAmt_sum   5410.0  235070.323475  6.339728e+05   0.0
# OPAnnualDeductibleAmt_mean     5410.0     629.095618  3.441041e+02   0.0
# OPAnnualDeductibleAmt_max      5410.0    3710.578189  2.769506e+03   0.0
# OPAnnualDeductibleAmt_sum      5410.0   67036.781146  1.812672e+05   0.0
# ClaimCounts                    5410.0     103.181331  2.724570e+02   1.0
# ...

# %%
df_num_cat.iloc[:,50:100].describe().T
# Out:
#                                         count        mean          std  min  \
# Chronic_Diabetes_Frac                  5410.0    0.707307     0.168950  0.0
# Chronic_IschemicHeart_Frac             5410.0    0.765842     0.153917  0.0
# Chronic_Osteoporasis_Frac              5410.0    0.320718     0.171529  0.0
# Chronic_rheumatoidarthritis_Frac       5410.0    0.309094     0.168559  0.0
# Chronic_stroke_Frac                    5410.0    0.104631     0.113676  0.0
# Deceased_Frac                          5410.0    0.007246     0.031529  0.0
# MaxDiagCodeNumPerClaim                 5410.0    8.150277     2.322526  0.0
# MeanDiagCodeNumPerClaim                5410.0    3.407356     1.727429  0.0
# MaxProcCodeNumPerClaim                 5410.0    0.750277     1.110266  0.0
# MeanProcCodeNumPerClaim                5410.0    0.108011     0.246305  0.0
# TotalDiagCodeNum                       5410.0  310.668392   761.374485  0.0
# ...

# %%
df_num_cat.iloc[:,100:].describe().T
# Out:
#                       count        mean          std       min        25%  \
# totalProcCode_2724   5410.0    0.000000     0.000000  0.000000   0.000000
# totalProcCode_8154   5410.0    0.000000     0.000000  0.000000   0.000000
# totalProcCode_66     5410.0    0.000000     0.000000  0.000000   0.000000
# totalProcCode_3893   5410.0    0.000000     0.000000  0.000000   0.000000
# totalProcCode_3995   5410.0    0.000000     0.000000  0.000000   0.000000
# totalProcCode_4516   5410.0    0.000000     0.000000  0.000000   0.000000
# totalProcCode_3722   5410.0    0.000000     0.000000  0.000000   0.000000
# totalProcCode_8151   5410.0    0.000000     0.000000  0.000000   0.000000
# totalProcCode_8872   5410.0    0.000000     0.000000  0.000000   0.000000
# totalProcCode_9671   5410.0    0.000000     0.000000  0.000000   0.000000
# totalProcCode_4513   5410.0    0.000000     0.000000  0.000000   0.000000
# totalProcCode_5849   5410.0    0.000000     0.000000  0.000000   0.000000
# ...
