# %%
import pandas as pd
import requests,json
df=pd.read_csv("app/data/X_test_0817.csv")
df.head()
# Out:
#    Provider  DeductibleAmtPaid_mean  DeductibleAmtPaid_max  \
# 0  PRV51003              502.166667                 1068.0
# 1  PRV51007               45.333333                 1068.0
# 2  PRV51025              164.183908                 1068.0
# 3  PRV51026                4.473684                  100.0
# 4  PRV51041                7.941176                  100.0
#
#    NoOfMonths_PartACov_mean  NoOfMonths_PartBCov_mean  \
# 0                 11.818182                 11.871212
# 1                 11.833333                 11.833333
# 2                 12.000000                 12.000000
# 3                 11.684211                 12.000000
# 4                 12.000000                 12.000000
#
#    OPAnnualReimbursementAmt_mean  OPAnnualReimbursementAmt_max  \
# 0                    2678.181818                         31880
# 1                    1729.722222                          6060
# 2                    2288.965517                         23330
# ...

# %%
test_row = df.iloc[0,1:].to_dict()
d = {'query':test_row}
url = 'http://127.0.0.1:5000/'
headers =  {'Content-type': 'application/json', 'Accept': 'text/plain'}

# %%
features=list(df.columns)

# %%
test_row
# Out:
# {'DeductibleAmtPaid_mean': 502.1666666666667,
#  'DeductibleAmtPaid_max': 1068.0,
#  'NoOfMonths_PartACov_mean': 11.818181818181818,
#  'NoOfMonths_PartBCov_mean': 11.87121212121212,
#  'OPAnnualReimbursementAmt_mean': 2678.181818181818,
#  'OPAnnualReimbursementAmt_max': 31880,
#  'OPAnnualReimbursementAmt_sum': 353520,
#  'OPAnnualDeductibleAmt_mean': 737.1212121212121,
#  'OPAnnualDeductibleAmt_max': 9950,
#  'OPAnnualDeductibleAmt_sum': 97300,
#  'ClaimCounts': 132,
#  'Gender': 0.409,
#  'ClaimPeriod': 4.674,
#  'RaceOneFrac': 0.811,
#  'MajorRace': 1,
#  'RenalDiseaseIndicator': 0.22,
#  'Age': 71.0,
#  'uniqBeneCount': 117,
#  'ClmsperBene': 1.1282051282051282,
#  'TotalInscClaimAmtReimbursed': 605670,
#  'MeanInscClaimAmtReimbursed': 4588.409090909091,
#  'MaxInscClaimAmtReimbursed': 57000,
#  'uniqATPhysnCount': 44,
#  'ClmsperATPhysn': 3.0,
#  'uniqOPPhysnCount': 7,
#  'ClmsperOPPhysn': 18.857142857142858,
#  'uniqOTPhysnCount': 22,
#  'ClmsperOTPhysn': 6.0,
# ...

# %%
response = requests.get(url, data=json.dumps(d),headers=headers,timeout=3)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'results': [{'label': 'Fraud', 'ModelScore': 0.6704263408890486}]}
